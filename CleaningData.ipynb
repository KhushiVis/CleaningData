# %%
import pandas as pd
import numpy as np

data = {
    'ord_no': [np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan, 70002.0, 70004.0, np.nan, 70006.0, np.nan, 70009.0, 70008.0, 70011.0, np.nan, 70013.0, 70007.0],
    'purch_amt': [270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60, 150.50],
    'ord_date': ['2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25', '2012-10-05'],
    'customer_id': [3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001, 3002],
    'salesman_id': [5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan, 5002.0]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
print("\nOriginal DataFrame shape:", df.shape)

df_clean = df.dropna()

print("\nDataFrame after dropping rows with missing values:")
print(df_clean)
print("\nCleaned DataFrame shape:", df_clean.shape)
# Out:
# Original DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0       NaN     270.65  2012-09-10         3001       5003.0
# 1   70002.0      65.26         NaN         3001       5001.0
# 2   70004.0     110.50  2012-08-17         3003          NaN
# 3       NaN     948.50  2012-09-10         3002       5002.0
# 4   70005.0    2400.60  2012-07-27         3001       5001.0
# 5       NaN    5760.00  2012-09-10         3001       5001.0
# 6   70010.0    1983.43  2012-10-10         3004          NaN
# 7   70003.0    2480.40  2012-10-10         3003       5003.0
# 8   70012.0     250.45  2012-06-27         3002       5002.0
# 9       NaN      75.29  2012-08-17         3001       5003.0
# 10      NaN     270.65  2012-09-10         3001       5003.0
# 11  70002.0      65.26         NaN         3001       5001.0
# 12  70004.0     110.50  2012-08-17         3003          NaN
# 13      NaN     948.50  2012-09-10         3002       5002.0
# ...
